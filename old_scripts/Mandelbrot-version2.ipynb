# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
def mandelbrot(c):
    z = complex(0,0)
    z1 = complex(10,0)
    while z1 != z:
        z1 = z**2 + c
        if not np.isnan(abs(z1)):
            color[c] = i
            return False
    return True

# %%
ar = np.linspace(-2,2,100)
init = np.array([ar + x*1j for x in ar]).flatten()


color = np.zeros(len(init))

mand = np.array([])
for i in init:
    if mandelbrot(i):
        mand = np.append(mand, i)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In [5], line 9
#       7 mand = np.array([])
#       8 for i in init:
# ----> 9     if mandelbrot(i):
#      10         mand = np.append(mand, i)
#
# Cell In [4], line 7, in mandelbrot(c)
#       5     z1 = z**2 + c
#       6     if not np.isnan(abs(z1)):
# ----> 7         color[c] = i
#       8         return False
#       9 return True
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
X = [x.real for x in mand]
Y = [x.imag for x in mand]

plt.figure(figsize=(10,10))
plt.scatter(X,Y, s=0.5, color='black')
plt.show()
