# %%
import matplotlib.pyplot as plt
import numpy as np

c = (-0.79 + 0.15j)

def julia(z):
    for j in range(300):
        z = z**2 + c
        if np.isnan(abs(z)):
            return False, j
    return True, 0

    
ar = np.linspace(-1.6,1.6,4320)
ac = np.linspace(-1.2,1.2,2880)
init = np.array([ar + x*1j for x in ac]).flatten()


colorchart = np.zeros(len(init))

mand = np.array([])
for i in range(len(init)):
    trueFalse, col = julia(init[i])
    
    colorchart[i] = col
    if trueFalse:
        mand = np.append(mand, init[i])


X = np.array([x.real for x in mand])
Y = np.array([x.imag for x in mand])

X1 = np.array([x.real for x in init])
Y1 = np.array([x.imag for x in init])



#Julia set coordinates:{(-0.79 + 0.15j), (0.28 + 0.008j)}
# Out:
# /var/folders/3p/sfv68y0d48x7855k_3bdlj8w0000gn/T/ipykernel_2536/1457787191.py:8: RuntimeWarning: overflow encountered in cdouble_scalars
#   z = z**2 + c
# /var/folders/3p/sfv68y0d48x7855k_3bdlj8w0000gn/T/ipykernel_2536/1457787191.py:8: RuntimeWarning: invalid value encountered in cdouble_scalars
#   z = z**2 + c

# %% [markdown]
# original:

# %%
plt.figure(figsize=(36,24))
plt.title('c = '+ str(c))
plt.axis('equal')
plt.scatter(X1,Y1, s=0.1, c=colorchart, cmap='prism')
#plt.scatter(X,Y, s=0.5, color='black')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/3p/sfv68y0d48x7855k_3bdlj8w0000gn/T/ipykernel_2536/2207921128.py in <module>
#       4 plt.scatter(X1,Y1, c=colorchart, cmap='prism')
#       5 #plt.scatter(X,Y, s=0.5, color='black')
# ----> 6 plt.show()
#       7
#
# /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/matplotlib/pyplot.py in show(*args, **kwargs)
#     366     """
#     367     _warn_if_gui_out_of_main_thread()
# --> 368     return _backend_mod.show(*args, **kwargs)
#     369
#     370
#
# /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/matplotlib_inline/backend_inline.py in show(close, block)
#      39     try:
#      40         for figure_manager in Gcf.get_all_fig_managers():
# ---> 41             display(
#      42                 figure_manager.canvas.figure,
# ...

# %%
plt.figure(figsize=(36,24), dpi=360)
plt.axis('equal')
plt.scatter(X1,Y1, c=colorchart, cmap='prism')
#plt.scatter(X,Y, s=0.5, color='black')

# linspace dots maybe = 36/s

#s = 

plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/3p/sfv68y0d48x7855k_3bdlj8w0000gn/T/ipykernel_2536/2311579787.py in <module>
#       9
#      10 plt.axis('off')
# ---> 11 plt.show()
#
# /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/matplotlib/pyplot.py in show(*args, **kwargs)
#     366     """
#     367     _warn_if_gui_out_of_main_thread()
# --> 368     return _backend_mod.show(*args, **kwargs)
#     369
#     370
#
# /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/matplotlib_inline/backend_inline.py in show(close, block)
#      39     try:
#      40         for figure_manager in Gcf.get_all_fig_managers():
# ---> 41             display(
#      42                 figure_manager.canvas.figure,
#      43                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#
# ...

# %%
plt.figure(dpi=360)
plt.axis('equal')
plt.scatter(X1,Y1, c=colorchart, cmap='prism')
plt.axis('off')
plt.show()

# %% [markdown]
# saving:

# %%
beingsaved = plt.figure(figsize=(36,24), dpi=1200)
plt.axis('equal')
plt.scatter(X1,Y1, c=colorchart, cmap='prism')
#plt.scatter(X,Y, s=0.5, color='black')

# linspace dots maybe = 36/s

#s = 

plt.axis('off')


beingsaved.savefig('destination_path_1200kindadpi.png', format='png')
